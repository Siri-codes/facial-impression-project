# %% [markdown]
# # Planning Notebook

# %% [markdown]
# ### Current To\-Dos:

# %% [markdown]
# - update Github

# %% [markdown]
# - \.\.\.

# %% [markdown]
# ### Research Question: \[\.\.\.\]

# %% [markdown]
# ### Models Tested:

# %% [markdown]
# <img src="Screenshot 2026-07-06 at 12.04.28 PM.png" width="" align="" />

# %% [markdown]
# ### Prompts To Test \(?\):

# %% [markdown]
# - Neutral Prompt

# %% [markdown]
# - quick vs\. slow thinking

# %% [markdown]
# - societal consequences \(hiring, legal sentencing\)

# %% [markdown]
# - distraction level / cognitive load

# %% [markdown]
# - have to back it up with evidence

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=db20d035-0f07-44b3-9147-5cdb9d6d1fdd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
